# %% [markdown]
# **Covid 19 Data Analysis**

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\NGC\Desktop\Python data analysis projects\Project 3\covid_19_data.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# **Confirmed, deaths and recovered cases of each region**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').sum()
# Out:
#                          Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan         4/29/2020     0       1939      60        252
# Albania             4/29/2020     0        766      30        455
# Algeria             4/29/2020     0       3848     444       1702
# Andorra             4/29/2020     0        743      42        423
# Angola              4/29/2020     0         27       2          7
# ...                       ...   ...        ...     ...        ...
# West Bank and Gaza  4/29/2020     0        344       2         71
# Western Sahara      4/29/2020     0          6       0          5
# Yemen               4/29/2020     0          6       0          1
# Zambia              4/29/2020     0         97       3         54
# Zimbabwe            4/29/2020     0         32       4          5
#
# [187 rows x 5 columns]

# %%
data.groupby('Region')[['Confirmed', 'Deaths','Recovered']].sum(numeric_only=True)
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
# **Remove all the confirmed cases < 15**

# %%
data[data.Confirmed < 15]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 27   4/29/2020                               NaN                Burundi
# 59   4/29/2020                               NaN                 Gambia
# 70   4/29/2020                               NaN               Holy See
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 118  4/29/2020                               NaN              Nicaragua
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 144  4/29/2020                               NaN             Seychelles
# 156  4/29/2020                               NaN               Suriname
# 177  4/29/2020                               NaN         Western Sahara
# ...

# %%
data = data[~(data.Confirmed < 15)]

# %%
data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %% [markdown]
# **In which Region maximum deaths cases were reported**

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                60965
# Italy             27682
# UK                26163
# Spain             24275
# France            24121
# Belgium            7501
# Germany            6467
# Iran               5957
# Brazil             5513
# Netherlands        4727
# Mainland China     4633
# Canada             3154
# Turkey             3081
# Sweden             2462
# Mexico             1732
# Switzerland        1716
# Ireland            1190
# India              1079
# Portugal            973
# Russia              972
# Name: Deaths, dtype: int64

# %% [markdown]
# **In which Region maximum Confirmed cases were reported**

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039895
# Spain              236899
# Italy              203591
# France             166536
# UK                 166396
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52836
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# **In which Region maximum Recovered cases were reported**

# %%
data.groupby('Region').Recovered.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# Spain             132929
# Germany           120400
# Mainland China     77609
# Iran               73791
# Italy              71252
# France             49112
# Turkey             44040
# Brazil             34132
# Switzerland        22600
# Ireland            13386
# Austria            12779
# Mexico             11423
# Belgium            11283
# Russia             10286
# Peru               10037
# South Korea         9059
# India               8437
# Israel              8233
# Chile               8057
# Denmark             6547
# Name: Recovered, dtype: int64

# %% [markdown]
# **In which Region minimum Deaths cases were reported**

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(30)
# Out:
# Region
# Central African Republic            0
# Cambodia                            0
# Grenada                             0
# Dominica                            0
# Eritrea                             0
# Fiji                                0
# Mongolia                            0
# Laos                                0
# Namibia                             0
# Madagascar                          0
# Macau                               0
# Mozambique                          0
# Nepal                               0
# Saint Kitts and Nevis               0
# Saint Lucia                         0
# Saint Vincent and the Grenadines    0
# Uganda                              0
# Vietnam                             0
# South Sudan                         0
# Timor-Leste                         0
# Rwanda                              0
# Liechtenstein                       1
# Botswana                            1
# Benin                               1
# ...

# %% [markdown]
# **Counts of Confirmed, Detahs, and Recovered cases for US till 29th of April 2020**

# %%
data[data.Region == 'US'].sum() # have to consider all records because all record are up to 29th April 2020
# Out:
# Date         4/29/20204/29/20204/29/20204/29/20204/29/20204...
# State        AlabamaAlaskaArizonaArkansasCaliforniaColorado...
# Region       USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# Confirmed                                              1039895
# Deaths                                                   60965
# Recovered                                                    0
# dtype: object

# %% [markdown]
# **Counts of Confirmed, Detahs, and Recovered cases for US till 29th of April 2020**

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# **Sort whole data set and find number of confirmed cases descending order**

# %%
data.sort_values( by = ['Confirmed'] , ascending = False).head(10)
# Out:
#           Date       State   Region  Confirmed  Deaths  Recovered
# 265  4/29/2020    New York       US     299691   23477          0
# 153  4/29/2020         NaN    Spain     236899   24275     132929
# 80   4/29/2020         NaN    Italy     203591   27682      71252
# 168  4/29/2020         NaN       UK     165221   26097          0
# 57   4/29/2020         NaN   France     165093   24087      48228
# 61   4/29/2020         NaN  Germany     161539    6467     120400
# 167  4/29/2020         NaN   Turkey     117589    3081      44040
# 262  4/29/2020  New Jersey       US     116365    6771          0
# 134  4/29/2020         NaN   Russia      99399     972      10286
# 76   4/29/2020         NaN     Iran      93657    5957      73791

# %% [markdown]
# **Sort whole data set and find number of confirmed cases ascending order**

# %%
data.sort_values( by = ['Confirmed'] , ascending = True)
# Out:
#           Date     State                            Region  Confirmed  Deaths  \
# 136  4/29/2020       NaN             Saint Kitts and Nevis         15       0
# 45   4/29/2020       NaN                          Dominica         16       0
# 201  4/29/2020   Curacao                       Netherlands         16       1
# 114  4/29/2020       NaN                           Namibia         16       0
# 138  4/29/2020       NaN  Saint Vincent and the Grenadines         16       0
# ..         ...       ...                               ...        ...     ...
# 57   4/29/2020       NaN                            France     165093   24087
# 168  4/29/2020       NaN                                UK     165221   26097
# 80   4/29/2020       NaN                             Italy     203591   27682
# 153  4/29/2020       NaN                             Spain     236899   24275
# 265  4/29/2020  New York                                US     299691   23477
#
#      Recovered
# 136          4
# ...

# %% [markdown]
# **Sort whole data set and find number of Deaths cases decending order**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values( by = ['Deaths'], ascending = False)
# Out:
#           Date               State          Region  Confirmed  Deaths  \
# 80   4/29/2020                 NaN           Italy     203591   27682
# 168  4/29/2020                 NaN              UK     165221   26097
# 153  4/29/2020                 NaN           Spain     236899   24275
# 57   4/29/2020                 NaN          France     165093   24087
# 265  4/29/2020            New York              US     299691   23477
# ..         ...                 ...             ...        ...     ...
# 64   4/29/2020                 NaN         Grenada         20       0
# 237  4/29/2020             Jiangsu  Mainland China        653       0
# 271  4/29/2020  Northern Territory       Australia         28       0
# 267  4/29/2020             Ningxia  Mainland China         75       0
# 51   4/29/2020                 NaN         Eritrea         39       0
#
#      Recovered
# 80       71252
# 168          0
# 153     132929
# 57       48228
# 265          0
# ..         ...
# ...

# %% [markdown]
# **Sort whole data set and find number of Deaths cases acending order**

# %%
data.sort_values( by = ['Deaths'], ascending = True)
# Out:
#           Date     State                    Region  Confirmed  Deaths  \
# 29   4/29/2020       NaN                  Cambodia        122       0
# 31   4/29/2020       NaN  Central African Republic         50       0
# 286  4/29/2020   Reunion                    France        420       0
# 281  4/29/2020   Qinghai            Mainland China         18       0
# 45   4/29/2020       NaN                  Dominica         16       0
# ..         ...       ...                       ...        ...     ...
# 265  4/29/2020  New York                        US     299691   23477
# 57   4/29/2020       NaN                    France     165093   24087
# 153  4/29/2020       NaN                     Spain     236899   24275
# 168  4/29/2020       NaN                        UK     165221   26097
# 80   4/29/2020       NaN                     Italy     203591   27682
#
#      Recovered
# 29         119
# 31          10
# 286        300
# 281         18
# 45          13
# ..         ...
# ...

# %% [markdown]
# **Sort whole data set and find number of Recovered cases decending order**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values( by = ['Recovered'], ascending = False)
# Out:
#           Date                      State          Region  Confirmed  Deaths  \
# 153  4/29/2020                        NaN           Spain     236899   24275
# 61   4/29/2020                        NaN         Germany     161539    6467
# 76   4/29/2020                        NaN            Iran      93657    5957
# 80   4/29/2020                        NaN           Italy     203591   27682
# 229  4/29/2020                      Hubei  Mainland China      68128    4512
# ..         ...                        ...             ...        ...     ...
# 266  4/29/2020  Newfoundland and Labrador          Canada        258       3
# 290  4/29/2020               Saskatchewan          Canada        383       6
# 287  4/29/2020               Rhode Island              US       8247     251
# 282  4/29/2020                     Quebec          Canada      26610    1762
# 298  4/29/2020             South Carolina              US       5882     231
#
#      Recovered
# 153     132929
# ...

# %% [markdown]
# **Sort whole data set and find number of Recovered cases ascending order**

# %%
data.sort_values( by = ['Recovered'], ascending
